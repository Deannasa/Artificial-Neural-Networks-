# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_valid, X_train = X_train[:4000], X_train[4000:] / 255
y_valid, y_train = y_train[:4000], y_train[4000:]
X_test = X_test / 255

# %%
plt.figure(figsize = (15, 4))
plotnumber = 1

for i in range(4):
    if plotnumber <= 4:
        ax = plt.subplot(1, 4, plotnumber)
        plt.imshow(X_train[i], cmap = 'binary')
        plt.axis('off')
        
    plotnumber += 1
  
plt.tight_layout()
plt.show()

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
class_names[y_train[0]], class_names[y_train[1]]
# Out:
# ('Bag', 'Coat')

# %%
plt.figure(figsize = (15, 6))
plotnumber = 1

for i in range(51):
    if plotnumber <= 50:
        ax = plt.subplot(5, 10, plotnumber)
        plt.imshow(X_train[i], cmap = 'binary')
        plt.axis('off')
        plt.title(class_names[y_train[i]], fontdict = {'fontsize'  : 12, 'color' : 'black'})
        
    plotnumber += 1
  
plt.tight_layout()
plt.show()

# %%
#model0 = keras.models.Sequential([
    #keras.layers.Flatten(input_shape = [28, 28]),
    #keras.layers.Dense(16, activation = 'sigmoid'),
    #keras.layers.Dense(16, activation = 'sigmoid'),
    #keras.layers.Dense(10, activation = 'sigmoid')
#])
#model0.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 16)                12560
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 13,002
# Trainable params: 13,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28, 28]),
    keras.layers.Dense(100, activation = 'relu'),
    keras.layers.Dense(70, activation = 'relu'),
    keras.layers.Dense(50, activation = 'relu'),
    keras.layers.Dense(20, activation = 'relu'),
    keras.layers.Dense(10, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 784)               0
#
#  dense_19 (Dense)            (None, 100)               78500
#
#  dense_20 (Dense)            (None, 70)                7070
#
#  dense_21 (Dense)            (None, 50)                3550
#
#  dense_22 (Dense)            (None, 20)                1020
#
#  dense_23 (Dense)            (None, 10)                210
#
# =================================================================
# Total params: 90,350
# Trainable params: 90,350
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(), metrics = ['accuracy'])

model_history = model.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs = 50)
# Out:
# Epoch 1/50
# 1750/1750 [==============================] - 8s 4ms/step - loss: 0.5330 - accuracy: 0.8104 - val_loss: 55.1819 - val_accuracy: 0.8490
# Epoch 2/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.3879 - accuracy: 0.8579 - val_loss: 72.5865 - val_accuracy: 0.8225
# Epoch 3/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.3497 - accuracy: 0.8707 - val_loss: 56.9572 - val_accuracy: 0.8540
# Epoch 4/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.3254 - accuracy: 0.8799 - val_loss: 47.3142 - val_accuracy: 0.8662
# Epoch 5/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.3080 - accuracy: 0.8861 - val_loss: 46.4143 - val_accuracy: 0.8597
# Epoch 6/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2947 - accuracy: 0.8915 - val_loss: 52.9782 - val_accuracy: 0.8428
# Epoch 7/50
# 1750/1750 [==============================] - 8s 4ms/step - loss: 0.2825 - accuracy: 0.8949 - val_loss: 46.4398 - val_accuracy: 0.8590
# Epoch 8/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2716 - accuracy: 0.8982 - val_loss: 43.3375 - val_accuracy: 0.8633
# Epoch 9/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2633 - accuracy: 0.9009 - val_loss: 44.2269 - val_accuracy: 0.8655
# Epoch 10/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2538 - accuracy: 0.9040 - val_loss: 57.9173 - val_accuracy: 0.8403
# Epoch 11/50
# 1750/1750 [==============================] - 8s 5ms/step - loss: 0.2469 - accuracy: 0.9071 - val_loss: 62.6889 - val_accuracy: 0.8503
# Epoch 12/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2403 - accuracy: 0.9093 - val_loss: 57.4968 - val_accuracy: 0.8580
# Epoch 13/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2290 - accuracy: 0.9131 - val_loss: 63.3565 - val_accuracy: 0.8575
# Epoch 14/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2270 - accuracy: 0.9134 - val_loss: 47.8814 - val_accuracy: 0.8800
# Epoch 15/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2201 - accuracy: 0.9163 - val_loss: 56.6455 - val_accuracy: 0.8710
# Epoch 16/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2137 - accuracy: 0.9187 - val_loss: 59.4413 - val_accuracy: 0.8520
# Epoch 17/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2091 - accuracy: 0.9209 - val_loss: 53.3005 - val_accuracy: 0.8725
# Epoch 18/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.2060 - accuracy: 0.9217 - val_loss: 58.5217 - val_accuracy: 0.8615
# Epoch 19/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.1979 - accuracy: 0.9246 - val_loss: 59.8144 - val_accuracy: 0.8637
# Epoch 20/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1929 - accuracy: 0.9270 - val_loss: 48.1373 - val_accuracy: 0.8740
# Epoch 21/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1898 - accuracy: 0.9281 - val_loss: 76.1626 - val_accuracy: 0.8447
# Epoch 22/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1870 - accuracy: 0.9292 - val_loss: 62.2450 - val_accuracy: 0.8730
# Epoch 23/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1844 - accuracy: 0.9301 - val_loss: 53.2614 - val_accuracy: 0.8737
# Epoch 24/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1793 - accuracy: 0.9319 - val_loss: 64.3799 - val_accuracy: 0.8470
# Epoch 25/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1755 - accuracy: 0.9338 - val_loss: 57.0577 - val_accuracy: 0.8687
# Epoch 26/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1691 - accuracy: 0.9361 - val_loss: 61.9857 - val_accuracy: 0.8612
# Epoch 27/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1666 - accuracy: 0.9368 - val_loss: 66.1108 - val_accuracy: 0.8633
# Epoch 28/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1646 - accuracy: 0.9371 - val_loss: 70.6294 - val_accuracy: 0.8640
# Epoch 29/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1619 - accuracy: 0.9387 - val_loss: 64.9744 - val_accuracy: 0.8723
# Epoch 30/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1567 - accuracy: 0.9398 - val_loss: 70.9326 - val_accuracy: 0.8512
# Epoch 31/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1570 - accuracy: 0.9401 - val_loss: 63.7258 - val_accuracy: 0.8687
# Epoch 32/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1538 - accuracy: 0.9417 - val_loss: 75.9117 - val_accuracy: 0.8530
# Epoch 33/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1497 - accuracy: 0.9434 - val_loss: 74.1820 - val_accuracy: 0.8615
# Epoch 34/50
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.1477 - accuracy: 0.9447 - val_loss: 78.3316 - val_accuracy: 0.8620
# Epoch 35/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1440 - accuracy: 0.9445 - val_loss: 70.4390 - val_accuracy: 0.8577
# Epoch 36/50
# 1750/1750 [==============================] - 8s 4ms/step - loss: 0.1439 - accuracy: 0.9451 - val_loss: 70.0869 - val_accuracy: 0.8605
# Epoch 37/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1388 - accuracy: 0.9468 - val_loss: 71.4416 - val_accuracy: 0.8637
# Epoch 38/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1382 - accuracy: 0.9471 - val_loss: 70.9981 - val_accuracy: 0.8660
# Epoch 39/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1362 - accuracy: 0.9490 - val_loss: 92.3083 - val_accuracy: 0.8390
# Epoch 40/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1347 - accuracy: 0.9486 - val_loss: 75.7917 - val_accuracy: 0.8600
# Epoch 41/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1276 - accuracy: 0.9517 - val_loss: 77.1496 - val_accuracy: 0.8733
# Epoch 42/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1337 - accuracy: 0.9504 - val_loss: 76.3655 - val_accuracy: 0.8577
# Epoch 43/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1255 - accuracy: 0.9524 - val_loss: 75.5724 - val_accuracy: 0.8673
# Epoch 44/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.1244 - accuracy: 0.9532 - val_loss: 73.9159 - val_accuracy: 0.8710
# Epoch 45/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1244 - accuracy: 0.9528 - val_loss: 89.3950 - val_accuracy: 0.8652
# Epoch 46/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1187 - accuracy: 0.9549 - val_loss: 81.4775 - val_accuracy: 0.8655
# Epoch 47/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1202 - accuracy: 0.9548 - val_loss: 90.2219 - val_accuracy: 0.8560
# Epoch 48/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1202 - accuracy: 0.9538 - val_loss: 80.1564 - val_accuracy: 0.8633
# Epoch 49/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1156 - accuracy: 0.9562 - val_loss: 89.1439 - val_accuracy: 0.8643
# Epoch 50/50
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.1139 - accuracy: 0.9575 - val_loss: 115.5933 - val_accuracy: 0.8468

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 51)
sns.lineplot(epoch, train_loss, label = 'Training accuracy')
sns.lineplot(epoch, val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
plt.show()

# %%
y_probs = model.predict(X_test)
y_preds = y_probs.argmax(axis = 1)

y_preds[:100]
# Out:
# 313/313 [==============================] - 2s 5ms/step
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7, 4, 5, 5, 3, 4, 1, 2, 2, 8, 0, 2, 5,
#        7, 5, 1, 2, 6, 0, 9, 3, 8, 8, 3, 3, 8, 0, 7, 5, 7, 9, 0, 1, 6, 9,
#        4, 7, 2, 1, 6, 2, 4, 4, 5, 8, 2, 2, 8, 4, 8, 0, 7, 7, 8, 5, 1, 1,
#        6, 4, 7, 8, 7, 0, 2, 6, 2, 3, 1, 2, 8, 4, 1, 8, 5, 9, 5, 0, 3, 2,
#        0, 2, 5, 3, 6, 7, 1, 8, 0, 1, 4, 2])

# %%
y_probs[2]
# Out:
# array([6.6513952e-34, 9.9999994e-01, 4.5208384e-30, 1.2985341e-34,
#        2.7920946e-27, 0.0000000e+00, 2.2207176e-19, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00], dtype=float32)

# %%
sum(y_preds == y_test)/(len(y_test))
# Out:
# 0.8829

# %%
# function for confusion matrix

import itertools
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black",
             size=text_size)

# %%
plt.style.use('seaborn-dark')
make_confusion_matrix(y_true=y_test, 
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(15, 15),
                      text_size=10)
