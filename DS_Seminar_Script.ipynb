# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
X_valid, X_train = X_train[:4000], X_train[4000:] / 255
y_valid, y_train = y_train[:4000], y_train[4000:]
X_test = X_test / 255

# %%
plt.figure(figsize = (15, 4))
plotnumber = 1

for i in range(4):
    if plotnumber <= 4:
        ax = plt.subplot(1, 4, plotnumber)
        plt.imshow(X_train[i], cmap = 'binary')
        plt.axis('off')
        
    plotnumber += 1
  
plt.tight_layout()
plt.show()

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
class_names[y_train[0]], class_names[y_train[1]]
# Out:
# ('Bag', 'Coat')

# %%
plt.figure(figsize = (15, 6))
plotnumber = 1

for i in range(51):
    if plotnumber <= 50:
        ax = plt.subplot(5, 10, plotnumber)
        plt.imshow(X_train[i], cmap = 'binary')
        plt.axis('off')
        plt.title(class_names[y_train[i]], fontdict = {'fontsize'  : 12, 'color' : 'black'})
        
    plotnumber += 1
  
plt.tight_layout()
plt.show()

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [28, 28]),
    keras.layers.Dense(100, activation = 'relu'),
    keras.layers.Dense(70, activation = 'relu'),
    keras.layers.Dense(50, activation = 'relu'),
    keras.layers.Dense(20, activation = 'relu'),
    keras.layers.Dense(10, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense_2 (Dense)             (None, 100)               78500
#
#  dense_3 (Dense)             (None, 70)                7070
#
#  dense_4 (Dense)             (None, 50)                3550
#
#  dense_5 (Dense)             (None, 20)                1020
#
#  dense_6 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 90,350
# Trainable params: 90,350
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(), metrics = ['accuracy'])

model_history = model.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs = 50)
# Out:
# Epoch 1/50
# 1750/1750 [==============================] - 9s 5ms/step - loss: 0.2452 - accuracy: 0.9073 - val_loss: 54.0458 - val_accuracy: 0.8627
# Epoch 2/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.2389 - accuracy: 0.9111 - val_loss: 62.1746 - val_accuracy: 0.8510
# Epoch 3/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.2299 - accuracy: 0.9131 - val_loss: 58.0031 - val_accuracy: 0.8562
# Epoch 4/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.2239 - accuracy: 0.9154 - val_loss: 47.2031 - val_accuracy: 0.8752
# Epoch 5/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.2194 - accuracy: 0.9169 - val_loss: 63.6465 - val_accuracy: 0.8475
# Epoch 6/50
# 1750/1750 [==============================] - 9s 5ms/step - loss: 0.2138 - accuracy: 0.9187 - val_loss: 66.6172 - val_accuracy: 0.8410
# Epoch 7/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.2087 - accuracy: 0.9207 - val_loss: 63.8363 - val_accuracy: 0.8572
# Epoch 8/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.2033 - accuracy: 0.9235 - val_loss: 58.3137 - val_accuracy: 0.8645
# Epoch 9/50
# 1750/1750 [==============================] - 15s 9ms/step - loss: 0.1996 - accuracy: 0.9241 - val_loss: 54.2011 - val_accuracy: 0.8675
# Epoch 10/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1939 - accuracy: 0.9251 - val_loss: 51.5494 - val_accuracy: 0.8735
# Epoch 11/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1886 - accuracy: 0.9283 - val_loss: 74.3546 - val_accuracy: 0.8505
# Epoch 12/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1864 - accuracy: 0.9291 - val_loss: 62.4143 - val_accuracy: 0.8622
# Epoch 13/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1836 - accuracy: 0.9306 - val_loss: 59.1587 - val_accuracy: 0.8662
# Epoch 14/50
# 1750/1750 [==============================] - 15s 9ms/step - loss: 0.1765 - accuracy: 0.9320 - val_loss: 69.7447 - val_accuracy: 0.8565
# Epoch 15/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1762 - accuracy: 0.9332 - val_loss: 70.5006 - val_accuracy: 0.8608
# Epoch 16/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1718 - accuracy: 0.9352 - val_loss: 70.7244 - val_accuracy: 0.8635
# Epoch 17/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1706 - accuracy: 0.9357 - val_loss: 97.1054 - val_accuracy: 0.8317
# Epoch 18/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1635 - accuracy: 0.9375 - val_loss: 69.2091 - val_accuracy: 0.8605
# Epoch 19/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1620 - accuracy: 0.9378 - val_loss: 74.3870 - val_accuracy: 0.8510
# Epoch 20/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1624 - accuracy: 0.9373 - val_loss: 70.1312 - val_accuracy: 0.8627
# Epoch 21/50
# 1750/1750 [==============================] - 12s 7ms/step - loss: 0.1557 - accuracy: 0.9396 - val_loss: 59.2460 - val_accuracy: 0.8587
# Epoch 22/50
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.1598 - accuracy: 0.9383 - val_loss: 80.4666 - val_accuracy: 0.8590
# Epoch 23/50
# 1750/1750 [==============================] - 11s 6ms/step - loss: 0.1510 - accuracy: 0.9420 - val_loss: 80.1189 - val_accuracy: 0.8480
# Epoch 24/50
# 1750/1750 [==============================] - 16s 9ms/step - loss: 0.1505 - accuracy: 0.9429 - val_loss: 68.2028 - val_accuracy: 0.8668
# Epoch 25/50
# 1750/1750 [==============================] - 18s 10ms/step - loss: 0.1490 - accuracy: 0.9432 - val_loss: 68.6561 - val_accuracy: 0.8587
# Epoch 26/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1458 - accuracy: 0.9454 - val_loss: 83.4163 - val_accuracy: 0.8558
# Epoch 27/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1443 - accuracy: 0.9455 - val_loss: 71.7973 - val_accuracy: 0.8558
# Epoch 28/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1422 - accuracy: 0.9457 - val_loss: 84.4273 - val_accuracy: 0.8648
# Epoch 29/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1418 - accuracy: 0.9465 - val_loss: 76.3166 - val_accuracy: 0.8593
# Epoch 30/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1342 - accuracy: 0.9485 - val_loss: 76.6026 - val_accuracy: 0.8658
# Epoch 31/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1332 - accuracy: 0.9488 - val_loss: 74.8350 - val_accuracy: 0.8735
# Epoch 32/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1329 - accuracy: 0.9501 - val_loss: 67.2830 - val_accuracy: 0.8708
# Epoch 33/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1315 - accuracy: 0.9490 - val_loss: 79.1390 - val_accuracy: 0.8692
# Epoch 34/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1317 - accuracy: 0.9495 - val_loss: 90.9739 - val_accuracy: 0.8710
# Epoch 35/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1271 - accuracy: 0.9514 - val_loss: 83.5340 - val_accuracy: 0.8830
# Epoch 36/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1266 - accuracy: 0.9513 - val_loss: 87.1953 - val_accuracy: 0.8605
# Epoch 37/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1226 - accuracy: 0.9526 - val_loss: 85.4915 - val_accuracy: 0.8670
# Epoch 38/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1269 - accuracy: 0.9516 - val_loss: 71.9663 - val_accuracy: 0.8675
# Epoch 39/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1216 - accuracy: 0.9532 - val_loss: 90.3322 - val_accuracy: 0.8652
# Epoch 40/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1161 - accuracy: 0.9556 - val_loss: 88.2819 - val_accuracy: 0.8690
# Epoch 41/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1150 - accuracy: 0.9559 - val_loss: 94.4538 - val_accuracy: 0.8683
# Epoch 42/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1167 - accuracy: 0.9563 - val_loss: 136.0044 - val_accuracy: 0.8403
# Epoch 43/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1150 - accuracy: 0.9559 - val_loss: 83.2232 - val_accuracy: 0.8752
# Epoch 44/50
# 1750/1750 [==============================] - 13s 7ms/step - loss: 0.1136 - accuracy: 0.9565 - val_loss: 84.1145 - val_accuracy: 0.8792
# Epoch 45/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1125 - accuracy: 0.9580 - val_loss: 90.7975 - val_accuracy: 0.8685
# Epoch 46/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1124 - accuracy: 0.9575 - val_loss: 94.4228 - val_accuracy: 0.8695
# Epoch 47/50
# 1750/1750 [==============================] - 14s 8ms/step - loss: 0.1080 - accuracy: 0.9595 - val_loss: 87.5876 - val_accuracy: 0.8675
# Epoch 48/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1100 - accuracy: 0.9586 - val_loss: 89.3294 - val_accuracy: 0.8685
# Epoch 49/50
# 1750/1750 [==============================] - 15s 9ms/step - loss: 0.1050 - accuracy: 0.9599 - val_loss: 85.1141 - val_accuracy: 0.8773
# Epoch 50/50
# 1750/1750 [==============================] - 13s 8ms/step - loss: 0.1048 - accuracy: 0.9602 - val_loss: 105.3387 - val_accuracy: 0.8670

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 51)
sns.lineplot(epoch, train_loss, label = 'Training accuracy')
sns.lineplot(epoch, val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')
plt.show()

# %%
y_probs = model.predict(X_test)
y_preds = y_probs.argmax(axis = 1)

y_preds[:100]
# Out:
# 313/313 [==============================] - 1s 2ms/step
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7, 4, 5, 5, 3, 4, 1, 2, 2, 8, 0, 2, 5,
#        7, 5, 1, 2, 6, 0, 9, 3, 8, 8, 3, 3, 8, 0, 7, 5, 7, 9, 0, 1, 6, 7,
#        6, 7, 2, 1, 2, 6, 4, 4, 5, 8, 2, 2, 8, 4, 8, 0, 7, 7, 8, 5, 1, 1,
#        6, 4, 7, 8, 7, 0, 2, 6, 2, 3, 1, 2, 8, 4, 1, 8, 5, 9, 5, 0, 3, 2,
#        0, 2, 5, 3, 6, 7, 1, 8, 0, 1, 4, 6])

# %%
y_probs[2]
# Out:
# array([8.2116144e-36, 9.9999994e-01, 0.0000000e+00, 1.0463828e-34,
#        2.2920062e-34, 0.0000000e+00, 4.4748311e-33, 0.0000000e+00,
#        3.6961560e-29, 0.0000000e+00], dtype=float32)

# %%
sum(y_preds == y_test)/(len(y_test))
# Out:
# 0.8889

# %%
# function for confusion matrix

import itertools
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black",
             size=text_size)

# %%
plt.style.use('seaborn-dark')
make_confusion_matrix(y_true=y_test, 
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(15, 15),
                      text_size=10)
